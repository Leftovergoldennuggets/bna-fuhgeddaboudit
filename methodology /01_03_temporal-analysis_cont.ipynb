# %% [markdown]
# # Time of Day Analysis
# To analyze time of day x crash frequency, 1) merge onto the NHTSA data by ID and then 2) plot crashes by time of day (by Waymo). Alternatively, just visualize NHTSA data directly (time of day).

# %% [markdown]
# # Time Alignment / Standardization
# - standardize by number of months (data collection time period, 3 - 6 mos) for each city
# - standardize by number of miles (how many miles waymos have traveled; use internet archive to grab the number of miles traveled in 3 mo increments; VMT basis rather than raw crash basis)

# %% [markdown]
# # Geographic Refinement
# - "enter what neighborhood you're in" (SF neighborhoods, instead of zipcode)

# %% [markdown]
# a
