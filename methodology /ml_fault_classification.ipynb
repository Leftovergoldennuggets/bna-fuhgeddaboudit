# %% [markdown]
# # Increasing Robustness to a Fault-Based Classification System

# %% [markdown]
# ## Fine-Tuned Classification Model (Supervised Learning)
# - train BERT, RoBERTa (transformer-based model) on a manually labeled subset of a couple hundred narratives with fault categories
# - active learning for iteractive improvement, or multi-task learning (predicting fault, then contact initiator, then movement status)
# - could use current keyword approach & add ML as a refinement layer

# %% [markdown]
# extra thoughts: could use KWIC approach?

# %% [markdown]
# ## Dependency Parsing + Entity Recognition
# - train spaCy, stanford CoreNLP, or other NER models to extract strucutred information (entities, relationships, subject-verb-object triples)
# - then build a fault logic based on the structured data
# - this wouldn't be too different from the current keyword approach

# %% [markdown]
# ## Exploring Data / Modelling

# %% [markdown]
# ### Topic Modeling
# - identify latent themes (e.g., use a LDA)to identify themes in crash narratives
# ### Temporal/Spatial Analysis
# - time of day, location clustering, patterns
